# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Controle de Versão III
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# Aluno [Fernando Moura](https://www.linkedin.com/in/fernando-moura/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Sistema de branchs;</li>
#   <li>Trabalhando com branchs;</li>
#   <li>Mover código entre branchs.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Setup

# %% [markdown]
# Para realizar os exercicios vamos configurar o `git` e trazer o projeto do GitHub para a a máquina virtual do Google Colab (ou na sua máquina local, as instruções são as mesmas). Para tanto, replique as atividades expostas na aula 1 deste módulo.

# %% [markdown]
# ### **1.1. Autenticação**

# %% [markdown]
# Nesta etapa, vamos configura o `git` com suas credenciais.

# %%
import os

username = "FernandoBmoura" # insira o seu nome de usuário do git
os.environ["GITHUB_USER"] = username

# !git config --global user.name "${GITHUB_USER}"

# %%
import os
from getpass import getpass

usermail = getpass()
os.environ["GITHUB_MAIL"] = usermail

# !git config --global user.email "${GITHUB_MAIL}"
# Out:
# ··········

# %%
import os
from getpass import getpass

usertoken = getpass()
os.environ["GITHUB_TOKEN"] = usertoken
# Out:
# ··········

# %% [markdown]
# ### **1.2. Projeto**

# %% [markdown]
# Nesta etapa, vamos trazer o projeto do GitHub para máquina local.

# %%
# !git clone https://${GITHUB_USER}:${GITHUB_TOKEN}@github.com/FernandoBMoura/Exercicio_17_EBAC.git # insira o link do seu repositório remoto
# Out:
# Cloning into 'Exercicio_17_EBAC'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 11 (delta 2), reused 6 (delta 1), pack-reused 0
# Receiving objects: 100% (11/11), 13.24 KiB | 13.24 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd /content/Exercicio_17_EBAC/
# Out:
# /content/Exercicio_17_EBAC

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Preço da gasolina

# %% [markdown]
# O código abaixo gera um arquivo com o preço médio de venda da gasolina na cidade de São Paulo nos 10 primeiros dias de Julho de 2021.

# %% [markdown]
# > **Nota**: Este arquivo é o mesmo do exercício do módulo anterior.

# %%
# %%writefile gasolina.csv
# dia,venda
# 1,5.11
# 2,4.99
# 3,5.02
# 4,5.21
# 5,5.07
# 6,5.09
# 7,5.13
# 8,5.12
# 9,4.94
# 10,5.03
# Out:
# Writing gasolina.csv

# %% [markdown]
# ### **2.1. Branch**

# %% [markdown]
# Crie uma branch chamada `develop` e aponte o context do `git` para a nova branch. Vamos simular uma atualização no exercício do módulo anterior.

# %%
# !git checkout -b develop main
# código de criação da branch develop
# Out:
# Switched to a new branch 'develop'

# %%
# !git branch -a
# Out:
# * develop
#   main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/main

# %%
# !git push origin develop
# Out:
# Total 0 (delta 0), reused 0 (delta 0), pack-reused 0
# remote:
# remote: Create a pull request for 'develop' on GitHub by visiting:
# remote:      https://github.com/FernandoBMoura/Exercicio_17_EBAC/pull/new/develop
# remote:
# To https://github.com/FernandoBMoura/Exercicio_17_EBAC.git
#  * [new branch]      develop -> develop

# %% [markdown]
# ### **2.2. Desenvolvimento**

# %% [markdown]
# Gere uma gráfico de linha utilizando os dados do arquivo `gasolina.csv` com o dia no eixo `x`
#  e o seu preço no eixo `y` utilizando os pacotes Python de sua preferência, como o Pandas e o Seaborn. Salve o gráfico no arquivo `gasolina.png` e o seu código Python de geração no arquivo `gasolina.py`.

# %% [markdown]
# > **Nota**: Este gráfico deve alguns elementos diferente do anterior, como título, legenda, etc.

# %%
import pandas as pd
import seaborn as sns

gasolina_df = pd.read_csv('gasolina.csv', sep=',')

with sns.axes_style ('whitegrid'):
  grafico_gasolina = sns.lineplot(data=gasolina_df, x='dia', y='venda')
  grafico_gasolina.set(title='Gasolina em São Paulo/SP nos 10 primeiros dias Julho/2021', xlabel='Data', ylabel='Venda')
  grafico_gasolina.get_figure().savefig(f"gasolina.png")# código de geração do gráfico

# %%
# %%writefile gasolina.py

import pandas as pd
import seaborn as sns

gasolina_df = pd.read_csv('gasolina.csv', sep=',')

with sns.axes_style ('whitegrid'):
  grafico_gasolina = sns.lineplot(data=gasolina_df, x='dia', y='venda')
  grafico_gasolina.set(title='Gasolina em São Paulo/SP nos 10 primeiros dias de Julho/2021', xlabel='Data', ylabel='Venda')
  grafico_gasolina.get_figure().savefig(f"gasolina.png")
# Out:
# Writing gasolina.py

# %% [markdown]
# ### **2.3. Git**

# %% [markdown]
# Utilizando os comandos do `git`, adicione e "commite" os arquivos gerados (base, código Python e gráfico) na branch `develop`.

# %%
# !git status
# comandos git para adicionar e commitar os arquivos
# Out:
# On branch develop
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	gasolina.csv
# 	gasolina.png
# 	gasolina.py
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add gasolina.png

# %%
# !git commit -m "arquivo gasolina.png atualizado"
# Out:
# [develop 620b77b] arquivo gasolina.png atualizado
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 gasolina.png

# %%
# !git add gasolina.py

# %%
# !git commit -m "arquivo gasolina.py atualizado"
# Out:
# [develop 31c40b1] arquivo gasolina.py atualizado
#  1 file changed, 10 insertions(+)
#  create mode 100644 gasolina.py

# %% [markdown]
# ### **2.4. Github**

# %% [markdown]
# Utilizando os comandos do `git`, envie o seu commit para o GitHub.

# %%
# !git status
# comandos git para enviar o commit para o GitHub
# Out:
# On branch develop
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	gasolina.csv
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git push origin develop
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 31.20 KiB | 7.80 MiB/s, done.
# Total 6 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/FernandoBMoura/Exercicio_17_EBAC.git
#    f98337c..31c40b1  develop -> develop

# %% [markdown]
# ### **2.5. Pull Request e Merge**

# %% [markdown]
# No GitHub, crie um *pull request* (PR) para enviar o código da branch de `develop` para a branch `main`. Ainda na plataforma online, confira as atualizações, aprove o PR e realize o *merge*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
